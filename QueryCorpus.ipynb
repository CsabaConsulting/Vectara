# %%
import json
import os
import requests

from typing import Any

customer_id = "2906470669"
corpus_id = "2"
api_key = os.getenv("VECTARA_API_KEY") or "VECTARA_API_KEY"

post_headers = {
    "x-api-key": api_key,
    "customer-id": customer_id
}

# %%
def _get_query_json(query_value: str, response_mode: bool):
    """ Returns a query json. """
    corpus_key = dict(
        customer_id=customer_id,
        corpus_id=corpus_id
    )
    if response_mode:
        corpus_key["semantics"] = "RESPONSE"

    query_obj = dict(
        query=query_value,
        num_results=10,
        corpus_key=[corpus_key]
    )
    query = dict(query=[query_obj])

    return json.dumps(query)

# %%
query = "What is ThruThink?"
response = requests.post(
    f"https://api.vectara.io/v1/query",
    data=_get_query_json(query, False),
    verify=True,
    headers=post_headers)

if response.status_code != 200:
    print(f"Query failed with code {response.status_code}, reason {response.reason}, text {response.text}")

print(f"Code {response.status_code}, reason {response.reason}, text {response.text}")

# %%
res = json.loads(response.text)

# %%
res
# Out:
# {'responseSet': [{'response': [{'text': 'Category: ThruThink\n',
#      'score': 0.7805325,
#      'metadata': [{'name': 'is_title', 'value': 'true'},
#       {'name': 'title_level', 'value': '3'}],
#      'documentIndex': 0,
#      'corpusKey': {'customerId': 0,
#       'corpusId': 2,
#       'semantics': 'DEFAULT',
#       'dim': [],
#       'metadataFilter': '',
#       'lexicalInterpolationConfig': None},
#      'resultOffset': 0,
#      'resultLength': 20},
#     {'text': 'Category: ThruThink\n',
#      'score': 0.7805325,
#      'metadata': [{'name': 'is_title', 'value': 'true'},
#       {'name': 'title_level', 'value': '3'}],
#      'documentIndex': 1,
#      'corpusKey': {'customerId': 0,
#       'corpusId': 2,
#       'semantics': 'DEFAULT',
#       'dim': [],
#       'metadataFilter': '',
#       'lexicalInterpolationConfig': None},
#      'resultOffset': 0,
#      'resultLength': 20},
#     {'text': 'ThruThink reserves the right to set an upper limit on the number of individual projects or combinations at some point in the future due to unforseen storage or computation issues in the future',
#      'score': 0.7763537,
#      'metadata': [{'name': 'title', 'value': 'Resource Usage Policy\n'},
#       {'name': 'breadcrumb',
#        'value': '["Pricing By Type of Accounts\\n","Category: ThruThink\\n"]'},
#       {'name': 'lang', 'value': 'eng'},
#       {'name': 'section', 'value': '4'},
#       {'name': 'offset', 'value': '0'},
#       {'name': 'len', 'value': '192'}],
#      'documentIndex': 1,
#      'corpusKey': {'customerId': 0,
#       'corpusId': 2,
#       'semantics': 'DEFAULT',
#       'dim': [],
#       'metadataFilter': '',
#       'lexicalInterpolationConfig': None},
#      'resultOffset': 0,
#      'resultLength': 192},
#     {'text': 'The ThruThink analysis presents the User Inputs on an Accrual  Basis.',
#      'score': 0.76887167,
#      'metadata': [{'name': 'title', 'value': 'Category: Accrual\n'},
#       {'name': 'breadcrumb', 'value': '["Accrual Basis\\n"]'},
#       {'name': 'lang', 'value': 'eng'},
#       {'name': 'offset', 'value': '424'},
#       {'name': 'len', 'value': '69'}],
#      'documentIndex': 2,
#      'corpusKey': {'customerId': 0,
#       'corpusId': 2,
#       'semantics': 'DEFAULT',
#       'dim': [],
#       'metadataFilter': '',
#       'lexicalInterpolationConfig': None},
#      'resultOffset': 0,
#      'resultLength': 69},
#     {'text': 'ARRAffinity                            App.thruthink.com    Used to distribute traffic to the website on      Session         HTTP Cookie\n                                                  several servers in order to optimize response\ntimes.',
#      'score': 0.76763815,
#      'metadata': [{'name': 'lang', 'value': 'eng'},
#       {'name': 'section', 'value': '54'},
#       {'name': 'offset', 'value': '0'},
#       {'name': 'len', 'value': '240'}],
#      'documentIndex': 3,
#      'corpusKey': {'customerId': 0,
#       'corpusId': 2,
#       'semantics': 'DEFAULT',
#       'dim': [],
#       'metadataFilter': '',
#       'lexicalInterpolationConfig': None},
#      'resultOffset': 0,
#      'resultLength': 240},
#     {'text': 'The ThruThink analysis illustrates the projected performance of a business in concert with its debt and equity structure.Before beginning the Input Process (Step Process), if there are historical operating results for the Company available, this information should be entered into the Historical Worksheet in the ThruThink analysis.',
#      'score': 0.766939,
#      'metadata': [{'name': 'title', 'value': 'Category: Summary\n'},
#       {'name': 'breadcrumb',
#        'value': '["Historical Worksheet - Before Beginning\\n"]'},
#       {'name': 'lang', 'value': 'eng'},
#       {'name': 'offset', 'value': '0'},
#       {'name': 'len', 'value': '332'}],
#      'documentIndex': 4,
#      'corpusKey': {'customerId': 0,
#       'corpusId': 2,
#       'semantics': 'DEFAULT',
#       'dim': [],
#       'metadataFilter': '',
#       'lexicalInterpolationConfig': None},
#      'resultOffset': 0,
#      'resultLength': 332},
#     {'text': 'If this is done prior to the input process, it will be helpful to the User in making some of the input decisions and lay out a basis of comparison in a similar format as the ThruThink analysis.The ThruThink Evaluation is for the "business deal" and uses information from the Historical Worksheet.',
#      'score': 0.7567626,
#      'metadata': [{'name': 'title', 'value': 'Category: Summary\n'},
#       {'name': 'breadcrumb',
#        'value': '["Historical Worksheet - Before Beginning\\n"]'},
#       {'name': 'lang', 'value': 'eng'},
#       {'name': 'offset', 'value': '333'},
#       {'name': 'len', 'value': '296'}],
#      'documentIndex': 4,
#      'corpusKey': {'customerId': 0,
#       'corpusId': 2,
#       'semantics': 'DEFAULT',
#       'dim': [],
#       'metadataFilter': '',
#       'lexicalInterpolationConfig': None},
#      'resultOffset': 0,
#      'resultLength': 296},
#     {'text': '__RequestVerificationToken  App.thruthink.com    Helps prevent Cross-Site Request Forgery        Session         HTTP Cookie',
#      'score': 0.7559734,
#      'metadata': [{'name': 'lang', 'value': 'eng'},
#       {'name': 'section', 'value': '52'},
#       {'name': 'offset', 'value': '0'},
#       {'name': 'len', 'value': '124'}],
#      'documentIndex': 3,
#      'corpusKey': {'customerId': 0,
#       'corpusId': 2,
#       'semantics': 'DEFAULT',
#       'dim': [],
#       'metadataFilter': '',
#       'lexicalInterpolationConfig': None},
#      'resultOffset': 0,
#      'resultLength': 124},
#     {'text': 'The ThruThink Deal Score is available with the Individual Quick Deal and the ThruThink subscription.The ThruThink Deal Score uses proprietary algorithms and relationships that evaluates multiple factors involving historical information, the transaction itself and the projections which result in an overall grade or score for the "Deal".',
#      'score': 0.75519806,
#      'metadata': [{'name': 'title', 'value': 'ThruThink Deal Score\n'},
#       {'name': 'breadcrumb',
#        'value': '["Pricing By Type of Accounts\\n","Category: ThruThink\\n"]'},
#       {'name': 'lang', 'value': 'eng'},
#       {'name': 'section', 'value': '1'},
#       {'name': 'offset', 'value': '451'},
#       {'name': 'len', 'value': '337'}],
#      'documentIndex': 1,
#      'corpusKey': {'customerId': 0,
#       'corpusId': 2,
#       'semantics': 'DEFAULT',
#       'dim': [],
#       'metadataFilter': '',
#       'lexicalInterpolationConfig': None},
#      'resultOffset': 0,
#      'resultLength': 337},
#     {'text': 'By sending the Data File to ThruThink, the User provides ThruThink permission to evaluate Users Data for the purposes of solving the Error.',
#      'score': 0.75493544,
#      'metadata': [{'name': 'title',
#        'value': 'Category: Errors, Warnings and Cautions\n'},
#       {'name': 'breadcrumb',
#        'value': '["In Case of Error - Send Data File to ThruThink\\n"]'},
#       {'name': 'lang', 'value': 'eng'},
#       {'name': 'offset', 'value': '443'},
#       {'name': 'len', 'value': '139'}],
#      'documentIndex': 5,
#      'corpusKey': {'customerId': 0,
#       'corpusId': 2,
#       'semantics': 'DEFAULT',
#       'dim': [],
#       'metadataFilter': '',
#       'lexicalInterpolationConfig': None},
#      'resultOffset': 0,
#      'resultLength': 139}],
#    'status': [],
#    'document': [{'id': 'ThruThink_CustomerAssistance.md',
#      'metadata': [{'name': 'title', 'value': 'Customer Assistance\n'},
#       {'name': 'category', 'value': 'ThruThink'},
#       {'name': 'category_slug', 'value': 'ThruThink'},
#       {'name': 'slug', 'value': 'CustomerAssistance'},
#       {'name': 'file_name', 'value': 'ThruThink_CustomerAssistance.md'}]},
#     {'id': 'ThruThink_PricingByTypeOfAccounts.md',
#      'metadata': [{'name': 'title', 'value': 'Pricing By Type of Accounts\n'},
#       {'name': 'category', 'value': 'ThruThink'},
#       {'name': 'category_slug', 'value': 'ThruThink'},
#       {'name': 'slug', 'value': 'PricingByTypeOfAccounts'},
#       {'name': 'file_name', 'value': 'ThruThink_PricingByTypeOfAccounts.md'}]},
#     {'id': 'Accrual_AccrualBasis.md',
#      'metadata': [{'name': 'title', 'value': 'Accrual Basis\n'},
#       {'name': 'category', 'value': 'Accrual'},
#       {'name': 'category_slug', 'value': 'Accrual'},
#       {'name': 'slug', 'value': 'AccrualBasis'},
#       {'name': 'file_name', 'value': 'Accrual_AccrualBasis.md'}]},
#     {'id': 'ThruThink Cookie Policy.pdf',
#      'metadata': [{'name': 'CreationDate', 'value': '1527555084'},
#       {'name': 'Producer', 'value': 'Microsoft® Word 2013'},
#       {'name': 'Creator', 'value': 'Microsoft® Word 2013'},
#       {'name': 'ModDate', 'value': '1527555084'},
#       {'name': 'title', 'value': 'Posted/Revised: May 26, 2018'},
#       {'name': 'url',
#        'value': 'https://app.thruthink.com/docs/ThruThink Cookie Policy.pdf'},
#       {'name': 'category', 'value': 'Customer Use Policies'},
#       {'name': 'category_slug', 'value': 'CookiePolicy'},
#       {'name': 'slug', 'value': ''},
#       {'name': 'file_name', 'value': 'ThruThink Cookie Policy.pdf'},
#       {'name': 'file_path', 'value': 'pdf/ThruThink Cookie Policy.pdf'}]},
#     {'id': 'Summary_HistoricalWorksheetBeforeBeginning.md',
#      'metadata': [{'name': 'title',
#        'value': 'Historical Worksheet - Before Beginning\n'},
#       {'name': 'category', 'value': 'Summary'},
#       {'name': 'category_slug', 'value': 'Summary'},
#       {'name': 'slug', 'value': 'HistoricalWorksheetBeforeBeginning'},
#       {'name': 'file_name',
#        'value': 'Summary_HistoricalWorksheetBeforeBeginning.md'}]},
#     {'id': 'ErrorsWarningsandCautions_InCaseofErrorSendDataFiletoThruThink.md',
#      'metadata': [{'name': 'title',
#        'value': 'In Case of Error - Send Data File to ThruThink\n'},
#       {'name': 'category', 'value': 'Errors, Warnings and Cautions'},
#       {'name': 'category_slug', 'value': 'ErrorsWarningsandCautions'},
#       {'name': 'slug', 'value': 'InCaseofErrorSendDataFiletoThruThink'},
#       {'name': 'file_name',
#        'value': 'ErrorsWarningsandCautions_InCaseofErrorSendDataFiletoThruThink.md'}]}],
#    'generated': [],
#    'summary': [],
#    'futureId': 1}],
#  'status': [],
#  'metrics': None}

# %%
response = requests.post(
    f"https://api.vectara.io/v1/query",
    data=_get_query_json(query, True),
    verify=True,
    headers=post_headers)

if response.status_code != 200:
    print(f"Query failed with code {response.status_code}, reason {response.reason}, text {response.text}")

# print(f"Code {response.status_code}, reason {response.reason}, text {response.text}")
res = json.loads(response.text)
res
# Out:
# {'responseSet': [{'response': [{'text': 'Category: ThruThink\n',
#      'score': 0.94266045,
#      'metadata': [{'name': 'is_title', 'value': 'true'},
#       {'name': 'title_level', 'value': '3'}],
#      'documentIndex': 0,
#      'corpusKey': {'customerId': 0,
#       'corpusId': 2,
#       'semantics': 'DEFAULT',
#       'dim': [],
#       'metadataFilter': '',
#       'lexicalInterpolationConfig': None},
#      'resultOffset': 0,
#      'resultLength': 20},
#     {'text': 'Category: ThruThink\n',
#      'score': 0.94266045,
#      'metadata': [{'name': 'is_title', 'value': 'true'},
#       {'name': 'title_level', 'value': '3'}],
#      'documentIndex': 1,
#      'corpusKey': {'customerId': 0,
#       'corpusId': 2,
#       'semantics': 'DEFAULT',
#       'dim': [],
#       'metadataFilter': '',
#       'lexicalInterpolationConfig': None},
#      'resultOffset': 0,
#      'resultLength': 20},
#     {'text': 'https://thruthink.com',
#      'score': 0.9377222,
#      'metadata': [{'name': 'lang', 'value': 'epo'},
#       {'name': 'section', 'value': '17'},
#       {'name': 'offset', 'value': '0'},
#       {'name': 'len', 'value': '21'}],
#      'documentIndex': 2,
#      'corpusKey': {'customerId': 0,
#       'corpusId': 2,
#       'semantics': 'DEFAULT',
#       'dim': [],
#       'metadataFilter': '',
#       'lexicalInterpolationConfig': None},
#      'resultOffset': 0,
#      'resultLength': 21},
#     {'text': 'thruthink.com                   uses the website.',
#      'score': 0.92275333,
#      'metadata': [{'name': 'lang', 'value': 'eng'},
#       {'name': 'section', 'value': '27'},
#       {'name': 'offset', 'value': '0'},
#       {'name': 'len', 'value': '49'}],
#      'documentIndex': 3,
#      'corpusKey': {'customerId': 0,
#       'corpusId': 2,
#       'semantics': 'DEFAULT',
#       'dim': [],
#       'metadataFilter': '',
#       'lexicalInterpolationConfig': None},
#      'resultOffset': 0,
#      'resultLength': 49},
#     {'text': 'For the ThruThink® application site',
#      'score': 0.9163288,
#      'metadata': [{'name': 'lang', 'value': 'eng'},
#       {'name': 'section', 'value': '20'},
#       {'name': 'offset', 'value': '0'},
#       {'name': 'len', 'value': '35'}],
#      'documentIndex': 2,
#      'corpusKey': {'customerId': 0,
#       'corpusId': 2,
#       'semantics': 'DEFAULT',
#       'dim': [],
#       'metadataFilter': '',
#       'lexicalInterpolationConfig': None},
#      'resultOffset': 0,
#      'resultLength': 35},
#     {'text': 'ThruThink Evaluation Input\n',
#      'score': 0.90565807,
#      'metadata': [{'name': 'is_title', 'value': 'true'},
#       {'name': 'title_level', 'value': '5'}],
#      'documentIndex': 4,
#      'corpusKey': {'customerId': 0,
#       'corpusId': 2,
#       'semantics': 'DEFAULT',
#       'dim': [],
#       'metadataFilter': '',
#       'lexicalInterpolationConfig': None},
#      'resultOffset': 0,
#      'resultLength': 27},
#     {'text': 'ThruThink Evaluation Input\n',
#      'score': 0.90565807,
#      'metadata': [{'name': 'is_title', 'value': 'true'},
#       {'name': 'title_level', 'value': '5'}],
#      'documentIndex': 5,
#      'corpusKey': {'customerId': 0,
#       'corpusId': 2,
#       'semantics': 'DEFAULT',
#       'dim': [],
#       'metadataFilter': '',
#       'lexicalInterpolationConfig': None},
#      'resultOffset': 0,
#      'resultLength': 27},
#     {'text': '(https://app.thruthink.com), y',
#      'score': 0.9004201,
#      'metadata': [{'name': 'lang', 'value': 'deu'},
#       {'name': 'section', 'value': '21'},
#       {'name': 'offset', 'value': '0'},
#       {'name': 'len', 'value': '30'}],
#      'documentIndex': 2,
#      'corpusKey': {'customerId': 0,
#       'corpusId': 2,
#       'semantics': 'DEFAULT',
#       'dim': [],
#       'metadataFilter': '',
#       'lexicalInterpolationConfig': None},
#      'resultOffset': 0,
#      'resultLength': 30},
#     {'text': 'This will be very helpful when reporting errors to ThruThink.',
#      'score': 0.8934756,
#      'metadata': [{'name': 'title',
#        'value': 'Category: Errors, Warnings and Cautions\n'},
#       {'name': 'breadcrumb',
#        'value': '["Project Status - OK / Warning / Error\\n"]'},
#       {'name': 'lang', 'value': 'eng'},
#       {'name': 'offset', 'value': '1855'},
#       {'name': 'len', 'value': '61'}],
#      'documentIndex': 6,
#      'corpusKey': {'customerId': 0,
#       'corpusId': 2,
#       'semantics': 'DEFAULT',
#       'dim': [],
#       'metadataFilter': '',
#       'lexicalInterpolationConfig': None},
#      'resultOffset': 0,
#      'resultLength': 61},
#     {'text': 'ThruThink Deal Score\n',
#      'score': 0.8858699,
#      'metadata': [{'name': 'is_title', 'value': 'true'},
#       {'name': 'title_level', 'value': '4'}],
#      'documentIndex': 1,
#      'corpusKey': {'customerId': 0,
#       'corpusId': 2,
#       'semantics': 'DEFAULT',
#       'dim': [],
#       'metadataFilter': '',
#       'lexicalInterpolationConfig': None},
#      'resultOffset': 0,
#      'resultLength': 21}],
#    'status': [],
#    'document': [{'id': 'ThruThink_CustomerAssistance.md',
#      'metadata': [{'name': 'title', 'value': 'Customer Assistance\n'},
#       {'name': 'category', 'value': 'ThruThink'},
#       {'name': 'category_slug', 'value': 'ThruThink'},
#       {'name': 'slug', 'value': 'CustomerAssistance'},
#       {'name': 'file_name', 'value': 'ThruThink_CustomerAssistance.md'}]},
#     {'id': 'ThruThink_PricingByTypeOfAccounts.md',
#      'metadata': [{'name': 'title', 'value': 'Pricing By Type of Accounts\n'},
#       {'name': 'category', 'value': 'ThruThink'},
#       {'name': 'category_slug', 'value': 'ThruThink'},
#       {'name': 'slug', 'value': 'PricingByTypeOfAccounts'},
#       {'name': 'file_name', 'value': 'ThruThink_PricingByTypeOfAccounts.md'}]},
#     {'id': 'ThruThink Privacy Policy.pdf',
#      'metadata': [{'name': 'CreationDate', 'value': '1527559442'},
#       {'name': 'Producer', 'value': 'Microsoft® Word 2013'},
#       {'name': 'Creator', 'value': 'Microsoft® Word 2013'},
#       {'name': 'ModDate', 'value': '1527559442'},
#       {'name': 'title', 'value': 'Posted/Revised: May 28, 2018'},
#       {'name': 'url',
#        'value': 'https://app.thruthink.com/docs/ThruThink Privacy Policy.pdf'},
#       {'name': 'category', 'value': 'Customer Use Policies'},
#       {'name': 'category_slug', 'value': 'PrivacyPolicy'},
#       {'name': 'slug', 'value': ''},
#       {'name': 'file_name', 'value': 'ThruThink Privacy Policy.pdf'},
#       {'name': 'file_path', 'value': 'pdf/ThruThink Privacy Policy.pdf'}]},
#     {'id': 'ThruThink Cookie Policy.pdf',
#      'metadata': [{'name': 'CreationDate', 'value': '1527555084'},
#       {'name': 'Producer', 'value': 'Microsoft® Word 2013'},
#       {'name': 'Creator', 'value': 'Microsoft® Word 2013'},
#       {'name': 'ModDate', 'value': '1527555084'},
#       {'name': 'title', 'value': 'Posted/Revised: May 26, 2018'},
#       {'name': 'url',
#        'value': 'https://app.thruthink.com/docs/ThruThink Cookie Policy.pdf'},
#       {'name': 'category', 'value': 'Customer Use Policies'},
#       {'name': 'category_slug', 'value': 'CookiePolicy'},
#       {'name': 'slug', 'value': ''},
#       {'name': 'file_name', 'value': 'ThruThink Cookie Policy.pdf'},
#       {'name': 'file_path', 'value': 'pdf/ThruThink Cookie Policy.pdf'}]},
#     {'id': 'HistoricalWorksheet_HistoricalWorksheetUnCompensatedOwnerContribution.md',
#      'metadata': [{'name': 'title',
#        'value': 'Historical Worksheet - Un-Compensated Owner Contribution\n'},
#       {'name': 'category', 'value': 'Historical Worksheet'},
#       {'name': 'category_slug', 'value': 'HistoricalWorksheet'},
#       {'name': 'slug',
#        'value': 'HistoricalWorksheetUnCompensatedOwnerContribution'},
#       {'name': 'file_name',
#        'value': 'HistoricalWorksheet_HistoricalWorksheetUnCompensatedOwnerContribution.md'}]},
#     {'id': 'OwnerCompensation_UnCompensatedOwnerContribution.md',
#      'metadata': [{'name': 'title',
#        'value': 'Un-Compensated Owner Contribution\n'},
#       {'name': 'category', 'value': 'Owner Compensation'},
#       {'name': 'category_slug', 'value': 'OwnerCompensation'},
#       {'name': 'slug', 'value': 'UnCompensatedOwnerContribution'},
#       {'name': 'file_name',
#        'value': 'OwnerCompensation_UnCompensatedOwnerContribution.md'}]},
#     {'id': 'ErrorsWarningsandCautions_ProjectStatusOKWarningError.md',
#      'metadata': [{'name': 'title',
#        'value': 'Project Status - OK / Warning / Error\n'},
#       {'name': 'category', 'value': 'Errors, Warnings and Cautions'},
#       {'name': 'category_slug', 'value': 'ErrorsWarningsandCautions'},
#       {'name': 'slug', 'value': 'ProjectStatusOKWarningError'},
#       {'name': 'file_name',
#        'value': 'ErrorsWarningsandCautions_ProjectStatusOKWarningError.md'}]}],
#    'generated': [],
#    'summary': [],
#    'futureId': 1}],
#  'status': [],
#  'metrics': None}

# %%
def _get_query_json(query_value: str, response_mode: bool):
    """ Returns a query json. """
    corpus_key = dict(
        customer_id=customer_id,
        corpus_id=corpus_id
    )
    if response_mode:
        corpus_key["semantics"] = "RESPONSE"

    summarizer = dict(
        summarizer_prompt_name="vectara-experimental-summary-ext-2023-10-23-med",
        response_lang="en",
        max_summarized_results=5
    )
    query_obj = dict(
        query=query_value,
        num_results=10,
        corpus_key=[corpus_key],
        summary=[summarizer]
    )
    query = dict(query=[query_obj])

    return json.dumps(query)

# %%
response = requests.post(
    f"https://api.vectara.io/v1/query",
    data=_get_query_json(query, False),
    verify=True,
    headers=post_headers)

if response.status_code != 200:
    print(f"Query failed with code {response.status_code}, reason {response.reason}, text {response.text}")

res = json.loads(response.text)
res
# Out:
# {'responseSet': [{'response': [{'text': 'Category: ThruThink\n',
#      'score': 0.7805325,
#      'metadata': [{'name': 'is_title', 'value': 'true'},
#       {'name': 'title_level', 'value': '3'}],
#      'documentIndex': 0,
#      'corpusKey': {'customerId': 0,
#       'corpusId': 2,
#       'semantics': 'DEFAULT',
#       'dim': [],
#       'metadataFilter': '',
#       'lexicalInterpolationConfig': None},
#      'resultOffset': 0,
#      'resultLength': 20},
#     {'text': 'Category: ThruThink\n',
#      'score': 0.7805325,
#      'metadata': [{'name': 'is_title', 'value': 'true'},
#       {'name': 'title_level', 'value': '3'}],
#      'documentIndex': 1,
#      'corpusKey': {'customerId': 0,
#       'corpusId': 2,
#       'semantics': 'DEFAULT',
#       'dim': [],
#       'metadataFilter': '',
#       'lexicalInterpolationConfig': None},
#      'resultOffset': 0,
#      'resultLength': 20},
#     {'text': 'ThruThink reserves the right to set an upper limit on the number of individual projects or combinations at some point in the future due to unforseen storage or computation issues in the future',
#      'score': 0.7763537,
#      'metadata': [{'name': 'title', 'value': 'Resource Usage Policy\n'},
#       {'name': 'breadcrumb',
#        'value': '["Pricing By Type of Accounts\\n","Category: ThruThink\\n"]'},
#       {'name': 'lang', 'value': 'eng'},
#       {'name': 'section', 'value': '4'},
#       {'name': 'offset', 'value': '0'},
#       {'name': 'len', 'value': '192'}],
#      'documentIndex': 1,
#      'corpusKey': {'customerId': 0,
#       'corpusId': 2,
#       'semantics': 'DEFAULT',
#       'dim': [],
#       'metadataFilter': '',
#       'lexicalInterpolationConfig': None},
#      'resultOffset': 0,
#      'resultLength': 192},
#     {'text': 'The ThruThink analysis presents the User Inputs on an Accrual  Basis.',
#      'score': 0.76887167,
#      'metadata': [{'name': 'title', 'value': 'Category: Accrual\n'},
#       {'name': 'breadcrumb', 'value': '["Accrual Basis\\n"]'},
#       {'name': 'lang', 'value': 'eng'},
#       {'name': 'offset', 'value': '424'},
#       {'name': 'len', 'value': '69'}],
#      'documentIndex': 2,
#      'corpusKey': {'customerId': 0,
#       'corpusId': 2,
#       'semantics': 'DEFAULT',
#       'dim': [],
#       'metadataFilter': '',
#       'lexicalInterpolationConfig': None},
#      'resultOffset': 0,
#      'resultLength': 69},
#     {'text': 'ARRAffinity                            App.thruthink.com    Used to distribute traffic to the website on      Session         HTTP Cookie\n                                                  several servers in order to optimize response\ntimes.',
#      'score': 0.76763815,
#      'metadata': [{'name': 'lang', 'value': 'eng'},
#       {'name': 'section', 'value': '54'},
#       {'name': 'offset', 'value': '0'},
#       {'name': 'len', 'value': '240'}],
#      'documentIndex': 3,
#      'corpusKey': {'customerId': 0,
#       'corpusId': 2,
#       'semantics': 'DEFAULT',
#       'dim': [],
#       'metadataFilter': '',
#       'lexicalInterpolationConfig': None},
#      'resultOffset': 0,
#      'resultLength': 240},
#     {'text': 'The ThruThink analysis illustrates the projected performance of a business in concert with its debt and equity structure.Before beginning the Input Process (Step Process), if there are historical operating results for the Company available, this information should be entered into the Historical Worksheet in the ThruThink analysis.',
#      'score': 0.766939,
#      'metadata': [{'name': 'title', 'value': 'Category: Summary\n'},
#       {'name': 'breadcrumb',
#        'value': '["Historical Worksheet - Before Beginning\\n"]'},
#       {'name': 'lang', 'value': 'eng'},
#       {'name': 'offset', 'value': '0'},
#       {'name': 'len', 'value': '332'}],
#      'documentIndex': 4,
#      'corpusKey': {'customerId': 0,
#       'corpusId': 2,
#       'semantics': 'DEFAULT',
#       'dim': [],
#       'metadataFilter': '',
#       'lexicalInterpolationConfig': None},
#      'resultOffset': 0,
#      'resultLength': 332},
#     {'text': 'If this is done prior to the input process, it will be helpful to the User in making some of the input decisions and lay out a basis of comparison in a similar format as the ThruThink analysis.The ThruThink Evaluation is for the "business deal" and uses information from the Historical Worksheet.',
#      'score': 0.7567626,
#      'metadata': [{'name': 'title', 'value': 'Category: Summary\n'},
#       {'name': 'breadcrumb',
#        'value': '["Historical Worksheet - Before Beginning\\n"]'},
#       {'name': 'lang', 'value': 'eng'},
#       {'name': 'offset', 'value': '333'},
#       {'name': 'len', 'value': '296'}],
#      'documentIndex': 4,
#      'corpusKey': {'customerId': 0,
#       'corpusId': 2,
#       'semantics': 'DEFAULT',
#       'dim': [],
#       'metadataFilter': '',
#       'lexicalInterpolationConfig': None},
#      'resultOffset': 0,
#      'resultLength': 296},
#     {'text': '__RequestVerificationToken  App.thruthink.com    Helps prevent Cross-Site Request Forgery        Session         HTTP Cookie',
#      'score': 0.7559734,
#      'metadata': [{'name': 'lang', 'value': 'eng'},
#       {'name': 'section', 'value': '52'},
#       {'name': 'offset', 'value': '0'},
#       {'name': 'len', 'value': '124'}],
#      'documentIndex': 3,
#      'corpusKey': {'customerId': 0,
#       'corpusId': 2,
#       'semantics': 'DEFAULT',
#       'dim': [],
#       'metadataFilter': '',
#       'lexicalInterpolationConfig': None},
#      'resultOffset': 0,
#      'resultLength': 124},
#     {'text': 'The ThruThink Deal Score is available with the Individual Quick Deal and the ThruThink subscription.The ThruThink Deal Score uses proprietary algorithms and relationships that evaluates multiple factors involving historical information, the transaction itself and the projections which result in an overall grade or score for the "Deal".',
#      'score': 0.75519806,
#      'metadata': [{'name': 'title', 'value': 'ThruThink Deal Score\n'},
#       {'name': 'breadcrumb',
#        'value': '["Pricing By Type of Accounts\\n","Category: ThruThink\\n"]'},
#       {'name': 'lang', 'value': 'eng'},
#       {'name': 'section', 'value': '1'},
#       {'name': 'offset', 'value': '451'},
#       {'name': 'len', 'value': '337'}],
#      'documentIndex': 1,
#      'corpusKey': {'customerId': 0,
#       'corpusId': 2,
#       'semantics': 'DEFAULT',
#       'dim': [],
#       'metadataFilter': '',
#       'lexicalInterpolationConfig': None},
#      'resultOffset': 0,
#      'resultLength': 337},
#     {'text': 'By sending the Data File to ThruThink, the User provides ThruThink permission to evaluate Users Data for the purposes of solving the Error.',
#      'score': 0.75493544,
#      'metadata': [{'name': 'title',
#        'value': 'Category: Errors, Warnings and Cautions\n'},
#       {'name': 'breadcrumb',
#        'value': '["In Case of Error - Send Data File to ThruThink\\n"]'},
#       {'name': 'lang', 'value': 'eng'},
#       {'name': 'offset', 'value': '443'},
#       {'name': 'len', 'value': '139'}],
#      'documentIndex': 5,
#      'corpusKey': {'customerId': 0,
#       'corpusId': 2,
#       'semantics': 'DEFAULT',
#       'dim': [],
#       'metadataFilter': '',
#       'lexicalInterpolationConfig': None},
#      'resultOffset': 0,
#      'resultLength': 139}],
#    'status': [],
#    'document': [{'id': 'ThruThink_CustomerAssistance.md',
#      'metadata': [{'name': 'title', 'value': 'Customer Assistance\n'},
#       {'name': 'category', 'value': 'ThruThink'},
#       {'name': 'category_slug', 'value': 'ThruThink'},
#       {'name': 'slug', 'value': 'CustomerAssistance'},
#       {'name': 'file_name', 'value': 'ThruThink_CustomerAssistance.md'}]},
#     {'id': 'ThruThink_PricingByTypeOfAccounts.md',
#      'metadata': [{'name': 'title', 'value': 'Pricing By Type of Accounts\n'},
#       {'name': 'category', 'value': 'ThruThink'},
#       {'name': 'category_slug', 'value': 'ThruThink'},
#       {'name': 'slug', 'value': 'PricingByTypeOfAccounts'},
#       {'name': 'file_name', 'value': 'ThruThink_PricingByTypeOfAccounts.md'}]},
#     {'id': 'Accrual_AccrualBasis.md',
#      'metadata': [{'name': 'title', 'value': 'Accrual Basis\n'},
#       {'name': 'category', 'value': 'Accrual'},
#       {'name': 'category_slug', 'value': 'Accrual'},
#       {'name': 'slug', 'value': 'AccrualBasis'},
#       {'name': 'file_name', 'value': 'Accrual_AccrualBasis.md'}]},
#     {'id': 'ThruThink Cookie Policy.pdf',
#      'metadata': [{'name': 'CreationDate', 'value': '1527555084'},
#       {'name': 'Producer', 'value': 'Microsoft® Word 2013'},
#       {'name': 'Creator', 'value': 'Microsoft® Word 2013'},
#       {'name': 'ModDate', 'value': '1527555084'},
#       {'name': 'title', 'value': 'Posted/Revised: May 26, 2018'},
#       {'name': 'url',
#        'value': 'https://app.thruthink.com/docs/ThruThink Cookie Policy.pdf'},
#       {'name': 'category', 'value': 'Customer Use Policies'},
#       {'name': 'category_slug', 'value': 'CookiePolicy'},
#       {'name': 'slug', 'value': ''},
#       {'name': 'file_name', 'value': 'ThruThink Cookie Policy.pdf'},
#       {'name': 'file_path', 'value': 'pdf/ThruThink Cookie Policy.pdf'}]},
#     {'id': 'Summary_HistoricalWorksheetBeforeBeginning.md',
#      'metadata': [{'name': 'title',
#        'value': 'Historical Worksheet - Before Beginning\n'},
#       {'name': 'category', 'value': 'Summary'},
#       {'name': 'category_slug', 'value': 'Summary'},
#       {'name': 'slug', 'value': 'HistoricalWorksheetBeforeBeginning'},
#       {'name': 'file_name',
#        'value': 'Summary_HistoricalWorksheetBeforeBeginning.md'}]},
#     {'id': 'ErrorsWarningsandCautions_InCaseofErrorSendDataFiletoThruThink.md',
#      'metadata': [{'name': 'title',
#        'value': 'In Case of Error - Send Data File to ThruThink\n'},
#       {'name': 'category', 'value': 'Errors, Warnings and Cautions'},
#       {'name': 'category_slug', 'value': 'ErrorsWarningsandCautions'},
#       {'name': 'slug', 'value': 'InCaseofErrorSendDataFiletoThruThink'},
#       {'name': 'file_name',
#        'value': 'ErrorsWarningsandCautions_InCaseofErrorSendDataFiletoThruThink.md'}]}],
#    'generated': [],
#    'summary': [],
#    'futureId': 1}],
#  'status': [],
#  'metrics': None}

# %%
query = "In ThruThink can I make adjustments on the Cash Flow Control page?"
response = requests.post(
    f"https://api.vectara.io/v1/query",
    data=_get_query_json(query, False),
    verify=True,
    headers=post_headers)

if response.status_code != 200:
    print(f"Query failed with code {response.status_code}, reason {response.reason}, text {response.text}")

# print(f"Code {response.status_code}, reason {response.reason}, text {response.text}")
res = json.loads(response.text)
res
# Out:
# {'responseSet': [{'response': [{'text': 'Even though the Historical Worksheet is a stand alone tool, the User may choose to use the Worksheet projections for the projections in the Cash Flow Control page which are the projections used in the ThruThink analysis.There is an input option that is available on the lower portion of the Historical Worksheet Input page that will incorporate the Worksheet projections into the ThruThink analysis.The Company sales total will be adjusted in the Sales Override Inputs on the Cash Flow Control page.Company COGS % of Sales will be adjusted in the COGS Percent of Sales Override Inputs on the Cash Flow Control page.The Company Operating Expense projections total will entered into the Cash Flow Operating Expense Input page which will show up on the Cash Flow Control page under Adjustments to Operating Expense.An adjustment will be made in the Scheduled Income/Expense page to zero out the effect of any inputs on those pages.Please Note-These projection adjustments will replace any manual override inputs made by the User in the Cash Flow Control to Sales Override and the COGS Percent of Sales Override.',
#      'score': 0.7916247,
#      'metadata': [{'name': 'title',
#        'value': 'Use Worksheet Projections for Cash Flow Control\n'},
#       {'name': 'breadcrumb',
#        'value': '["Historical Worksheet\\n","Category: Summary\\n"]'},
#       {'name': 'lang', 'value': 'eng'},
#       {'name': 'offset', 'value': '0'},
#       {'name': 'len', 'value': '1108'}],
#      'documentIndex': 0,
#      'corpusKey': {'customerId': 0,
#       'corpusId': 2,
#       'semantics': 'DEFAULT',
#       'dim': [],
#       'metadataFilter': '',
#       'lexicalInterpolationConfig': None},
#      'resultOffset': 0,
#      'resultLength': 1108},
#     {'text': 'If the button is not used, the User will need to proceed to either the Cash Flow Control page or Step 3, the Sales/EBITDA Input page to make alternate inputs.When the Input to Cash Flow Control button is used, the updates to the Cash Flow Control page are referred to as Worksheet Adjustments and are made in order that the Cash Flow Control page will match the Worksheet projections.If the Input to Cash Flow Control button has been used, the Worksheet Adjustments may also be removed by selecting the Remove Option found in the Input to Cash Flow Control button.After updating the Cash Flow Control page with the Worksheet Adjustments, if inputs from another source occur, the User should remove the old Worksheet Adjustments and repeat the process to re-enter updated Worksheet Adjustments.',
#      'score': 0.7785512,
#      'metadata': [{'name': 'title',
#        'value': 'Category: Historical Worksheet\n'},
#       {'name': 'breadcrumb',
#        'value': '["Historical Worksheet - Input to Cash Flow Control\\n..."]'},
#       {'name': 'lang', 'value': 'eng'},
#       {'name': 'offset', 'value': '346'},
#       {'name': 'len', 'value': '793'}],
#      'documentIndex': 1,
#      'corpusKey': {'customerId': 0,
#       'corpusId': 2,
#       'semantics': 'DEFAULT',
#       'dim': [],
#       'metadataFilter': '',
#       'lexicalInterpolationConfig': None},
#      'resultOffset': 0,
#      'resultLength': 793},
#     {'text': 'The Cash Flow Control (see Browser - Workflow) adjustment for Other Current Debt can only be used to pay down the Individually Scheduled Debt portion.',
#      'score': 0.770183,
#      'metadata': [{'name': 'title',
#        'value': 'Other Current Debt - Individually Scheduled\n'},
#       {'name': 'breadcrumb',
#        'value': '["Debt Adjustments\\n","Category: Liabilities\\n","Other Transaction Debt\\n"]'},
#       {'name': 'lang', 'value': 'eng'},
#       {'name': 'section', 'value': '8'},
#       {'name': 'offset', 'value': '648'},
#       {'name': 'len', 'value': '150'}],
#      'documentIndex': 2,
#      'corpusKey': {'customerId': 0,
#       'corpusId': 2,
#       'semantics': 'DEFAULT',
#       'dim': [],
#       'metadataFilter': '',
#       'lexicalInterpolationConfig': None},
#      'resultOffset': 0,
#      'resultLength': 150},
#     {'text': 'The Cash Flow Control (see Browser - Workflow) adjustment for Other Current Debt can be used to increase or decrease the General Other Current Debt portion.',
#      'score': 0.76713175,
#      'metadata': [{'name': 'title',
#        'value': 'Other Current Debt - General Amounts\n'},
#       {'name': 'breadcrumb',
#        'value': '["Debt Adjustments\\n","Category: Liabilities\\n","Other Transaction Debt\\n"]'},
#       {'name': 'lang', 'value': 'eng'},
#       {'name': 'section', 'value': '6'},
#       {'name': 'offset', 'value': '1565'},
#       {'name': 'len', 'value': '156'}],
#      'documentIndex': 2,
#      'corpusKey': {'customerId': 0,
#       'corpusId': 2,
#       'semantics': 'DEFAULT',
#       'dim': [],
#       'metadataFilter': '',
#       'lexicalInterpolationConfig': None},
#      'resultOffset': 0,
#      'resultLength': 156},
#     {'text': 'If inputs are made here, the User will continue to have the opportunity to make adjustments on the Cash Flow Control page which will then override inputs made on this page.',
#      'score': 0.7669287,
#      'metadata': [{'name': 'title', 'value': 'Category: EBITDA\n'},
#       {'name': 'breadcrumb', 'value': '["EBITDA Input\\n"]'},
#       {'name': 'lang', 'value': 'eng'},
#       {'name': 'offset', 'value': '1565'},
#       {'name': 'len', 'value': '172'}],
#      'documentIndex': 3,
#      'corpusKey': {'customerId': 0,
#       'corpusId': 2,
#       'semantics': 'DEFAULT',
#       'dim': [],
#       'metadataFilter': '',
#       'lexicalInterpolationConfig': None},
#      'resultOffset': 0,
#      'resultLength': 172},
#     {'text': 'If inputs are made here, the User will continue to have the opportunity to make adjustments on the Cash Flow Control page which will then override inputs made on this page.',
#      'score': 0.7669287,
#      'metadata': [{'name': 'title', 'value': 'Category: Expenses\n'},
#       {'name': 'breadcrumb', 'value': '["Expense Input\\n"]'},
#       {'name': 'lang', 'value': 'eng'},
#       {'name': 'offset', 'value': '1565'},
#       {'name': 'len', 'value': '172'}],
#      'documentIndex': 4,
#      'corpusKey': {'customerId': 0,
#       'corpusId': 2,
#       'semantics': 'DEFAULT',
#       'dim': [],
#       'metadataFilter': '',
#       'lexicalInterpolationConfig': None},
#      'resultOffset': 0,
#      'resultLength': 172},
#     {'text': 'If inputs are made here, the User will continue to have the opportunity to make adjustments on the Cash Flow Control page which will then override inputs made on this page.',
#      'score': 0.7669287,
#      'metadata': [{'name': 'title', 'value': 'Category: Income\n'},
#       {'name': 'breadcrumb', 'value': '["Income Input\\n"]'},
#       {'name': 'lang', 'value': 'eng'},
#       {'name': 'offset', 'value': '1565'},
#       {'name': 'len', 'value': '172'}],
#      'documentIndex': 5,
#      'corpusKey': {'customerId': 0,
#       'corpusId': 2,
#       'semantics': 'DEFAULT',
#       'dim': [],
#       'metadataFilter': '',
#       'lexicalInterpolationConfig': None},
#      'resultOffset': 0,
#      'resultLength': 172},
#     {'text': 'The Cash Flow Control (see Browser - Workflow) adjustment for Other Current Debt can be used to increase or decrease the General Other Current Debt portion.',
#      'score': 0.76666987,
#      'metadata': [{'name': 'title',
#        'value': 'Other Current Debt - Credit Line\n'},
#       {'name': 'breadcrumb',
#        'value': '["Other Current Debt and Credit Line\\n","Category: Liabilities\\n"]'},
#       {'name': 'lang', 'value': 'eng'},
#       {'name': 'section', 'value': '1'},
#       {'name': 'offset', 'value': '1747'},
#       {'name': 'len', 'value': '156'}],
#      'documentIndex': 6,
#      'corpusKey': {'customerId': 0,
#       'corpusId': 2,
#       'semantics': 'DEFAULT',
#       'dim': [],
#       'metadataFilter': '',
#       'lexicalInterpolationConfig': None},
#      'resultOffset': 0,
#      'resultLength': 156},
#     {'text': 'The Credit Line feature of ThruThink may be turned on by entering a Credit Limit amount In Step 6 which will apply to the portion of the beginning Other Current Debt entered that is not a part of the Individually Scheduled Other Current Debt.',
#      'score': 0.76539844,
#      'metadata': [{'name': 'title',
#        'value': 'Other Current Debt - Credit Line\n'},
#       {'name': 'breadcrumb',
#        'value': '["Debt Adjustments\\n","Category: Liabilities\\n","Other Transaction Debt\\n"]'},
#       {'name': 'lang', 'value': 'eng'},
#       {'name': 'section', 'value': '7'},
#       {'name': 'offset', 'value': '0'},
#       {'name': 'len', 'value': '242'}],
#      'documentIndex': 2,
#      'corpusKey': {'customerId': 0,
#       'corpusId': 2,
#       'semantics': 'DEFAULT',
#       'dim': [],
#       'metadataFilter': '',
#       'lexicalInterpolationConfig': None},
#      'resultOffset': 0,
#      'resultLength': 242},
#     {'text': 'This is done while reviewing the Cash Flow results on the Cash Flow Control page and is a good method to adjust Sales and Expenses while being able to see the resulting financial impact.For more detailed Sales and Expense inputs the Individual Scheduled Item pages may be used to input individual Sales and Expense projections in detail.',
#      'score': 0.7534478,
#      'metadata': [{'name': 'title', 'value': 'Category: Expenses\n'},
#       {'name': 'breadcrumb', 'value': '["Expense Projections\\n"]'},
#       {'name': 'lang', 'value': 'eng'},
#       {'name': 'offset', 'value': '679'},
#       {'name': 'len', 'value': '337'}],
#      'documentIndex': 7,
#      'corpusKey': {'customerId': 0,
#       'corpusId': 2,
#       'semantics': 'DEFAULT',
#       'dim': [],
#       'metadataFilter': '',
#       'lexicalInterpolationConfig': None},
#      'resultOffset': 0,
#      'resultLength': 337}],
#    'status': [],
#    'document': [{'id': 'Summary_HistoricalWorksheet.md',
#      'metadata': [{'name': 'title', 'value': 'Historical Worksheet\n'},
#       {'name': 'category', 'value': 'Summary'},
#       {'name': 'category_slug', 'value': 'Summary'},
#       {'name': 'slug', 'value': 'HistoricalWorksheet'},
#       {'name': 'file_name', 'value': 'Summary_HistoricalWorksheet.md'}]},
#     {'id': 'HistoricalWorksheet_HistoricalWorksheetInputtoCashFlowControl.md',
#      'metadata': [{'name': 'title',
#        'value': 'Historical Worksheet - Input to Cash Flow Control\n'},
#       {'name': 'category', 'value': 'Historical Worksheet'},
#       {'name': 'category_slug', 'value': 'HistoricalWorksheet'},
#       {'name': 'slug', 'value': 'HistoricalWorksheetInputtoCashFlowControl'},
#       {'name': 'file_name',
#        'value': 'HistoricalWorksheet_HistoricalWorksheetInputtoCashFlowControl.md'}]},
#     {'id': 'Liabilities_DebtAdjustments.md',
#      'metadata': [{'name': 'title', 'value': 'Debt Adjustments\n'},
#       {'name': 'category', 'value': 'Liabilities'},
#       {'name': 'category_slug', 'value': 'Liabilities'},
#       {'name': 'slug', 'value': 'DebtAdjustments'},
#       {'name': 'file_name', 'value': 'Liabilities_DebtAdjustments.md'}]},
#     {'id': 'EBITDA_EBITDAInput.md',
#      'metadata': [{'name': 'title', 'value': 'EBITDA Input\n'},
#       {'name': 'category', 'value': 'EBITDA'},
#       {'name': 'category_slug', 'value': 'EBITDA'},
#       {'name': 'slug', 'value': 'EBITDAInput'},
#       {'name': 'file_name', 'value': 'EBITDA_EBITDAInput.md'}]},
#     {'id': 'Expenses_ExpenseInput.md',
#      'metadata': [{'name': 'title', 'value': 'Expense Input\n'},
#       {'name': 'category', 'value': 'Expenses'},
#       {'name': 'category_slug', 'value': 'Expenses'},
#       {'name': 'slug', 'value': 'ExpenseInput'},
#       {'name': 'file_name', 'value': 'Expenses_ExpenseInput.md'}]},
#     {'id': 'Income_IncomeInput.md',
#      'metadata': [{'name': 'title', 'value': 'Income Input\n'},
#       {'name': 'category', 'value': 'Income'},
#       {'name': 'category_slug', 'value': 'Income'},
#       {'name': 'slug', 'value': 'IncomeInput'},
#       {'name': 'file_name', 'value': 'Income_IncomeInput.md'}]},
#     {'id': 'Liabilities_OtherCurrentDebtandCreditLine.md',
#      'metadata': [{'name': 'title',
#        'value': 'Other Current Debt and Credit Line\n'},
#       {'name': 'category', 'value': 'Liabilities'},
#       {'name': 'category_slug', 'value': 'Liabilities'},
#       {'name': 'slug', 'value': 'OtherCurrentDebtandCreditLine'},
#       {'name': 'file_name',
#        'value': 'Liabilities_OtherCurrentDebtandCreditLine.md'}]},
#     {'id': 'Expenses_ExpenseProjections.md',
#      'metadata': [{'name': 'title', 'value': 'Expense Projections\n'},
#       {'name': 'category', 'value': 'Expenses'},
#       {'name': 'category_slug', 'value': 'Expenses'},
#       {'name': 'slug', 'value': 'ExpenseProjections'},
#       {'name': 'file_name', 'value': 'Expenses_ExpenseProjections.md'}]}],
#    'generated': [],
#    'summary': [],
#    'futureId': 1}],
#  'status': [],
#  'metrics': None}

# %%
def _get_query_json(query_value: str, response_mode: bool, no_title: bool):
    """ Returns a query json. """
    corpus_key = dict(
        customer_id=customer_id,
        corpus_id=corpus_id
    )
    if response_mode:
        corpus_key["semantics"] = "RESPONSE"
    if no_title:
        corpus_key["metadata_filter"] = "part.is_title = true"

    summarizer = dict(
        summarizer_prompt_name="vectara-experimental-summary-ext-2023-10-23-med",
        response_lang="en",
        max_summarized_results=5
    )
    query_obj = dict(
        query=query_value,
        num_results=10,
        corpus_key=[corpus_key],
        summary=[summarizer]
    )
    query = dict(query=[query_obj])

    return json.dumps(query)

# %%
query = "In ThruThink can I make adjustments on the Cash Flow Control page?"
response = requests.post(
    f"https://api.vectara.io/v1/query",
    data=_get_query_json(query, False, True),
    verify=True,
    headers=post_headers)

if response.status_code != 200:
    print(f"Query failed with code {response.status_code}, reason {response.reason}, text {response.text}")

# print(f"Code {response.status_code}, reason {response.reason}, text {response.text}")
res = json.loads(response.text)
res
# Out:
# {'responseSet': [{'response': [{'text': 'Cash Flow Control\n',
#      'score': 0.7177544,
#      'metadata': [{'name': 'is_title', 'value': 'true'},
#       {'name': 'title_level', 'value': '4'}],
#      'documentIndex': 0,
#      'corpusKey': {'customerId': 0,
#       'corpusId': 2,
#       'semantics': 'DEFAULT',
#       'dim': [],
#       'metadataFilter': '',
#       'lexicalInterpolationConfig': None},
#      'resultOffset': 0,
#      'resultLength': 18},
#     {'text': 'Cash Flow Control\n',
#      'score': 0.7177544,
#      'metadata': [{'name': 'title_level', 'value': '1'},
#       {'name': 'is_title', 'value': 'true'},
#       {'name': 'lang', 'value': 'eng'}],
#      'documentIndex': 1,
#      'corpusKey': {'customerId': 0,
#       'corpusId': 2,
#       'semantics': 'DEFAULT',
#       'dim': [],
#       'metadataFilter': '',
#       'lexicalInterpolationConfig': None},
#      'resultOffset': 0,
#      'resultLength': 18},
#     {'text': 'Cash Flow Control\n',
#      'score': 0.717396,
#      'metadata': [{'name': 'is_title', 'value': 'true'},
#       {'name': 'title_level', 'value': '2'}],
#      'documentIndex': 1,
#      'corpusKey': {'customerId': 0,
#       'corpusId': 2,
#       'semantics': 'DEFAULT',
#       'dim': [],
#       'metadataFilter': '',
#       'lexicalInterpolationConfig': None},
#      'resultOffset': 0,
#      'resultLength': 18},
#     {'text': 'Cash Flow Control Payments\n',
#      'score': 0.7123822,
#      'metadata': [{'name': 'is_title', 'value': 'true'},
#       {'name': 'title_level', 'value': '4'}],
#      'documentIndex': 2,
#      'corpusKey': {'customerId': 0,
#       'corpusId': 2,
#       'semantics': 'DEFAULT',
#       'dim': [],
#       'metadataFilter': '',
#       'lexicalInterpolationConfig': None},
#      'resultOffset': 0,
#      'resultLength': 27},
#     {'text': 'Use Worksheet Projections for Cash Flow Control\n',
#      'score': 0.7087545,
#      'metadata': [{'name': 'is_title', 'value': 'true'},
#       {'name': 'title_level', 'value': '4'}],
#      'documentIndex': 3,
#      'corpusKey': {'customerId': 0,
#       'corpusId': 2,
#       'semantics': 'DEFAULT',
#       'dim': [],
#       'metadataFilter': '',
#       'lexicalInterpolationConfig': None},
#      'resultOffset': 0,
#      'resultLength': 48},
#     {'text': 'Historical Worksheet - Input to Cash Flow Control\n',
#      'score': 0.6978693,
#      'metadata': [{'name': 'title_level', 'value': '1'},
#       {'name': 'is_title', 'value': 'true'},
#       {'name': 'lang', 'value': 'eng'}],
#      'documentIndex': 4,
#      'corpusKey': {'customerId': 0,
#       'corpusId': 2,
#       'semantics': 'DEFAULT',
#       'dim': [],
#       'metadataFilter': '',
#       'lexicalInterpolationConfig': None},
#      'resultOffset': 0,
#      'resultLength': 50},
#     {'text': 'Historical Worksheet - Input to Cash Flow Control\n',
#      'score': 0.69726413,
#      'metadata': [{'name': 'is_title', 'value': 'true'},
#       {'name': 'title_level', 'value': '2'}],
#      'documentIndex': 4,
#      'corpusKey': {'customerId': 0,
#       'corpusId': 2,
#       'semantics': 'DEFAULT',
#       'dim': [],
#       'metadataFilter': '',
#       'lexicalInterpolationConfig': None},
#      'resultOffset': 0,
#      'resultLength': 50},
#     {'text': 'Excess Payments from Cash Flow Control\n',
#      'score': 0.6849066,
#      'metadata': [{'name': 'is_title', 'value': 'true'},
#       {'name': 'title_level', 'value': '4'}],
#      'documentIndex': 5,
#      'corpusKey': {'customerId': 0,
#       'corpusId': 2,
#       'semantics': 'DEFAULT',
#       'dim': [],
#       'metadataFilter': '',
#       'lexicalInterpolationConfig': None},
#      'resultOffset': 0,
#      'resultLength': 39},
#     {'text': 'In Case of Error - Send Data File to ThruThink\n',
#      'score': 0.6741539,
#      'metadata': [{'name': 'title_level', 'value': '1'},
#       {'name': 'is_title', 'value': 'true'},
#       {'name': 'lang', 'value': 'eng'}],
#      'documentIndex': 6,
#      'corpusKey': {'customerId': 0,
#       'corpusId': 2,
#       'semantics': 'DEFAULT',
#       'dim': [],
#       'metadataFilter': '',
#       'lexicalInterpolationConfig': None},
#      'resultOffset': 0,
#      'resultLength': 47},
#     {'text': 'In Case of Error - Send Data File to ThruThink\n',
#      'score': 0.6738956,
#      'metadata': [{'name': 'is_title', 'value': 'true'},
#       {'name': 'title_level', 'value': '2'}],
#      'documentIndex': 6,
#      'corpusKey': {'customerId': 0,
#       'corpusId': 2,
#       'semantics': 'DEFAULT',
#       'dim': [],
#       'metadataFilter': '',
#       'lexicalInterpolationConfig': None},
#      'resultOffset': 0,
#      'resultLength': 47}],
#    'status': [],
#    'document': [{'id': 'Liabilities_DebtAdjustments.md',
#      'metadata': [{'name': 'title', 'value': 'Debt Adjustments\n'},
#       {'name': 'category', 'value': 'Liabilities'},
#       {'name': 'category_slug', 'value': 'Liabilities'},
#       {'name': 'slug', 'value': 'DebtAdjustments'},
#       {'name': 'file_name', 'value': 'Liabilities_DebtAdjustments.md'}]},
#     {'id': 'Cash_CashFlowControl.md',
#      'metadata': [{'name': 'title', 'value': 'Cash Flow Control\n'},
#       {'name': 'category', 'value': 'Cash'},
#       {'name': 'category_slug', 'value': 'Cash'},
#       {'name': 'slug', 'value': 'CashFlowControl'},
#       {'name': 'file_name', 'value': 'Cash_CashFlowControl.md'}]},
#     {'id': 'Liabilities_SubordinatedDebt.md',
#      'metadata': [{'name': 'title', 'value': 'Subordinated Debt\n'},
#       {'name': 'category', 'value': 'Liabilities'},
#       {'name': 'category_slug', 'value': 'Liabilities'},
#       {'name': 'slug', 'value': 'SubordinatedDebt'},
#       {'name': 'file_name', 'value': 'Liabilities_SubordinatedDebt.md'}]},
#     {'id': 'Summary_HistoricalWorksheet.md',
#      'metadata': [{'name': 'title', 'value': 'Historical Worksheet\n'},
#       {'name': 'category', 'value': 'Summary'},
#       {'name': 'category_slug', 'value': 'Summary'},
#       {'name': 'slug', 'value': 'HistoricalWorksheet'},
#       {'name': 'file_name', 'value': 'Summary_HistoricalWorksheet.md'}]},
#     {'id': 'HistoricalWorksheet_HistoricalWorksheetInputtoCashFlowControl.md',
#      'metadata': [{'name': 'title',
#        'value': 'Historical Worksheet - Input to Cash Flow Control\n'},
#       {'name': 'category', 'value': 'Historical Worksheet'},
#       {'name': 'category_slug', 'value': 'HistoricalWorksheet'},
#       {'name': 'slug', 'value': 'HistoricalWorksheetInputtoCashFlowControl'},
#       {'name': 'file_name',
#        'value': 'HistoricalWorksheet_HistoricalWorksheetInputtoCashFlowControl.md'}]},
#     {'id': 'Liabilities_SellerDebt.md',
#      'metadata': [{'name': 'title', 'value': 'Seller Debt\n'},
#       {'name': 'category', 'value': 'Liabilities'},
#       {'name': 'category_slug', 'value': 'Liabilities'},
#       {'name': 'slug', 'value': 'SellerDebt'},
#       {'name': 'file_name', 'value': 'Liabilities_SellerDebt.md'}]},
#     {'id': 'ErrorsWarningsandCautions_InCaseofErrorSendDataFiletoThruThink.md',
#      'metadata': [{'name': 'title',
#        'value': 'In Case of Error - Send Data File to ThruThink\n'},
#       {'name': 'category', 'value': 'Errors, Warnings and Cautions'},
#       {'name': 'category_slug', 'value': 'ErrorsWarningsandCautions'},
#       {'name': 'slug', 'value': 'InCaseofErrorSendDataFiletoThruThink'},
#       {'name': 'file_name',
#        'value': 'ErrorsWarningsandCautions_InCaseofErrorSendDataFiletoThruThink.md'}]}],
#    'generated': [],
#    'summary': [{'text': 'The returned results did not contain sufficient information to be summarized into a useful answer for your query. Please try a different search or restate your query differently.',
#      'lang': 'eng',
#      'prompt': '',
#      'status': [],
#      'futureId': 2}],
#    'futureId': 1}],
#  'status': [],
#  'metrics': None}

# %%
def _get_query_json(query_value: str, response_mode: bool, no_title: bool):
    """ Returns a query json. """
    corpus_key = dict(
        customer_id=customer_id,
        corpus_id=corpus_id
    )
    if response_mode:
        corpus_key["semantics"] = "RESPONSE"
    if no_title:
        corpus_key["metadata_filter"] = "part.is_title = false"

    summarizer = dict(
        summarizer_prompt_name="vectara-experimental-summary-ext-2023-10-23-med",
        response_lang="en",
        max_summarized_results=5
    )
    query_obj = dict(
        query=query_value,
        num_results=10,
        corpus_key=[corpus_key],
        summary=[summarizer]
    )
    query = dict(query=[query_obj])

    return json.dumps(query)

# %%
query = "In ThruThink can I make adjustments on the Cash Flow Control page?"
response = requests.post(
    f"https://api.vectara.io/v1/query",
    data=_get_query_json(query, False, True),
    verify=True,
    headers=post_headers)

if response.status_code != 200:
    print(f"Query failed with code {response.status_code}, reason {response.reason}, text {response.text}")

# print(f"Code {response.status_code}, reason {response.reason}, text {response.text}")
res = json.loads(response.text)
res
# Out:
# {'responseSet': [{'response': [],
#    'status': [],
#    'document': [],
#    'generated': [],
#    'summary': [{'text': '',
#      'lang': '',
#      'prompt': '',
#      'status': [{'code': 'QRY__SMRY__NO_QUERY_RESULTS',
#        'statusDetail': 'Summarization failed as there are no query results.',
#        'cause': None}],
#      'futureId': 2}],
#    'futureId': 1}],
#  'status': [],
#  'metrics': None}
